# %%
import torch
import functools
import einops
import requests
import pandas as pd
import io
import textwrap
import gc

from datasets import load_dataset
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from torch import Tensor
from typing import List, Callable
from transformer_lens import HookedTransformer, utils
from transformer_lens.hook_points import HookPoint
from transformers import AutoTokenizer
from jaxtyping import Float, Int
from colorama import Fore

# %%
MODEL_PATH = 'Qwen/Qwen-1_8B-chat'
DEVICE = 'cuda'

# %%
from pipeline.run_pipeline import run_pipeline

# %%
candidate_directions, direction, pos, layer = run_pipeline(MODEL_PATH)
# Out:
# config.json:   0%|          | 0.00/910 [00:00<?, ?B/s]
# configuration_qwen.py:   0%|          | 0.00/2.35k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-1_8B-chat:
# - configuration_qwen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_qwen.py:   0%|          | 0.00/55.6k [00:00<?, ?B/s]
# cpp_kernels.py:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-1_8B-chat:
# - cpp_kernels.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# qwen_generation_utils.py:   0%|          | 0.00/14.6k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-1_8B-chat:
# - qwen_generation_utils.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-1_8B-chat:
# - modeling_qwen.py
# - cpp_kernels.py
# - qwen_generation_utils.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/14.7k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/2.04G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Warning: import flash_attn rotary fail, please install FlashAttention rotary to get higher efficiency https://github.com/Dao-AILab/flash-attention/tree/main/csrc/rotary
# Warning: import flash_attn rms_norm fail, please install FlashAttention layer_norm to get higher efficiency https://github.com/Dao-AILab/flash-attention/tree/main/csrc/layer_norm
# Warning: import flash_attn fail, please install FlashAttention to get higher efficiency https://github.com/Dao-AILab/flash-attention
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/249 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# tokenization_qwen.py:   0%|          | 0.00/9.62k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-1_8B-chat:
# - tokenization_qwen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# qwen.tiktoken:   0%|          | 0.00/2.56M [00:00<?, ?B/s]
# /home/kartik/refusal_direction/venv/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 100%|██████████| 4/4 [00:00<00:00,  7.81it/s]
# 100%|██████████| 4/4 [00:00<00:00,  7.14it/s]
# Computing KL for source position -5: 100%|██████████| 24/24 [00:04<00:00,  5.38it/s]
# Computing KL for source position -4: 100%|██████████| 24/24 [00:03<00:00,  6.21it/s]
# Computing KL for source position -3: 100%|██████████| 24/24 [00:03<00:00,  6.35it/s]
# Computing KL for source position -2: 100%|██████████| 24/24 [00:03<00:00,  6.36it/s]
# Computing KL for source position -1: 100%|██████████| 24/24 [00:03<00:00,  6.33it/s]
# Computing refusal ablation for source position -5: 100%|██████████| 24/24 [00:02<00:00, 11.82it/s]
# Computing refusal ablation for source position -4: 100%|██████████| 24/24 [00:02<00:00, 11.69it/s]
# Computing refusal ablation for source position -3: 100%|██████████| 24/24 [00:02<00:00, 11.68it/s]
# Computing refusal ablation for source position -2: 100%|██████████| 24/24 [00:02<00:00, 11.62it/s]
# Computing refusal ablation for source position -1: 100%|██████████| 24/24 [00:02<00:00, 11.73it/s]
# Computing refusal addition for source position -5: 100%|██████████| 24/24 [00:03<00:00,  6.48it/s]
# Computing refusal addition for source position -4: 100%|██████████| 24/24 [00:03<00:00,  6.59it/s]
# Computing refusal addition for source position -3: 100%|██████████| 24/24 [00:03<00:00,  6.55it/s]
# Computing refusal addition for source position -2: 100%|██████████| 24/24 [00:03<00:00,  6.56it/s]
# Computing refusal addition for source position -1: 100%|██████████| 24/24 [00:03<00:00,  6.54it/s]
# Selected direction: position=-2, layer=15
# Refusal score: -5.0585 (baseline: 1.9751)
# Steering score: 1.6505 (baseline: -6.5421)
# KL Divergence: 0.0653
# 100%|██████████| 13/13 [04:11<00:00, 19.34s/it]
# 100%|██████████| 13/13 [05:35<00:00, 25.79s/it]
# 100%|██████████| 13/13 [04:34<00:00, 21.09s/it]
# Average Substring Matching ASR: 0.3
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 candidate_directions, direction, pos, layer = run_pipeline(MODEL_PATH)
#
# File ~/refusal_direction/pipeline/run_pipeline.py:167, in run_pipeline(model_path)
#     165 # 3b. Evaluate completions and save results on harmful evaluation datasets
#     166 for dataset_name in cfg.evaluation_datasets:
# --> 167     evaluate_completions_and_save_results_for_dataset(cfg, 'baseline', dataset_name, eval_methodologies=cfg.jailbreak_eval_methodologies)
#     168     evaluate_completions_and_save_results_for_dataset(cfg, 'ablation', dataset_name, eval_methodologies=cfg.jailbreak_eval_methodologies)
#     169     evaluate_completions_and_save_results_for_dataset(cfg, 'actadd', dataset_name, eval_methodologies=cfg.jailbreak_eval_methodologies)
#
# File ~/refusal_direction/pipeline/run_pipeline.py:115, in evaluate_completions_and_save_results_for_dataset(cfg, intervention_label, dataset_name, eval_methodologies)
#     112 with open(os.path.join(cfg.artifact_path(), f'completions/{dataset_name}_{intervention_label}_completions.json'), 'r') as f:
#     113     completions = json.load(f)
# --> 115 evaluation = evaluate_jailbreak(
#     116     completions=completions,
#     117     methodologies=eval_methodologies,
#     118     evaluation_path=os.path.join(cfg.artifact_path(), "completions", f"{dataset_name}_{intervention_label}_evaluations.json"),
#     119 )
#     121 with open(f'{cfg.artifact_path()}/completions/{dataset_name}_{intervention_label}_evaluations.json', "w") as f:
#     122     json.dump(evaluation, f, indent=4)
#
# File ~/refusal_direction/pipeline/submodules/evaluate_jailbreak.py:220, in evaluate_jailbreak(completions, completions_path, methodologies, evaluation_path)
#     216     print(f"Average Substring Matching ASR: {evaluation['substring_matching_success_rate']}")
#     218 if "llamaguard2" in methodologies:
# --> 220     classifications: List[int] = llamaguard2_judge_fn(prompts, responses)
#     222     for completion, classification in zip(completions, classifications):
#     223         completion["is_jailbreak_llamaguard2"] = int(classification)
#
# File ~/refusal_direction/pipeline/submodules/evaluate_jailbreak.py:126, in llamaguard2_judge_fn(prompts, responses)
#     125 def llamaguard2_judge_fn(prompts: List[str], responses: List[str]) -> List[int]:
# --> 126     assert os.environ.get("TOGETHER_API_KEY", None) is not None, "TOGETHER_API_KEY environment variable must be set to run jailbreakbench evaluation."
#     128     classifier = LlamaGuard2Classifier(os.environ["TOGETHER_API_KEY"])
#     130     batch_size = 20  # Adjust this value based on the API's rate limits
#
# AssertionError: TOGETHER_API_KEY environment variable must be set to run jailbreakbench evaluation.

# %%
pos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pos
#
# NameError: name 'pos' is not defined
